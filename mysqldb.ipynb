# %%
import mysql.connector
import pandas as pd

# %%
mydb = mysql.connector.connect(host="localhost",
                               user="root",
                               password="",
                               database="latihan")

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute('SELECT * FROM customers')

# %%
result = mycursor.fetchall()

# %%
result
# Out:
# [(1,
#   'Alfreds Futterkiste',
#   'Maria Anders',
#   'Obere Str. 57',
#   'Berlin',
#   '12209',
#   'Germany'),
#  (2,
#   'Ana Trujillo Emparedados y helados',
#   'Ana Trujillo',
#   'Avda. de la Constitución 2222',
#   'México D.F.',
#   '05021',
#   'Mexico'),
#  (3,
#   'Antonio Moreno Taquería',
#   'Antonio Moreno',
#   'Mataderos 2312',
#   'México D.F.',
#   '05023',
#   'Mexico'),
#  (4,
#   'Around the Horn',
#   'Thomas Hardy',
#   '120 Hanover Sq.',
#   'London',
#   'WA1 1DP',
#   'UK'),
#  (5,
#   'Berglunds snabbköp',
#   'Christina Berglund',
#   'Berguvsvägen 8',
#   'Luleå',
#   'S-958 22',
#   'Sweden'),
#  (6,
#   'Blauer See Delikatessen',
#   'Hanna Moos',
#   'Forsterstr. 57',
#   'Mannheim',
#   '68306',
#   'Germany'),
#  (7,
#   'Blondel père et fils',
#   'Frédérique Citeaux',
#   '24, place Kléber',
#   'Strasbourg',
#   '67000',
#   'France'),
#  (8,
#   'Bólido Comidas preparadas',
#   'Martín Sommer',
#   'C/ Araquil, 67',
#   'Madrid',
# ...

# %%
for i in result:
    print(i)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')
# (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain')
# (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France')
# ...

# %%
sql = "SELECT * FROM customers"

df = pd.read_sql(sql, mydb)
# Out:
# C:\Users\mfahm\AppData\Local\Temp\ipykernel_18780\3795753847.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, mydb)

# %%
df
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
df.to_csv("data_sql.csv", index=False)

# %%
df.to_excel("data_sql.xlsx", index=False)

# %%
df2 = pd.read_csv("data_sql.csv")

# %%
df2
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
df
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    91 non-null     int64
#  1   CustomerName  91 non-null     object
#  2   ContactName   91 non-null     object
#  3   Address       91 non-null     object
#  4   City          91 non-null     object
#  5   PostalCode    91 non-null     object
#  6   Country       91 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.1+ KB

# %%
df.head()
# Out:
#    CustomerID                        CustomerName         ContactName  \
# 0           1                 Alfreds Futterkiste        Maria Anders
# 1           2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2           3             Antonio Moreno Taquería      Antonio Moreno
# 3           4                     Around the Horn        Thomas Hardy
# 4           5                  Berglunds snabbköp  Christina Berglund
#
#                          Address         City PostalCode  Country
# 0                  Obere Str. 57       Berlin      12209  Germany
# 1  Avda. de la Constitución 2222  México D.F.      05021   Mexico
# 2                 Mataderos 2312  México D.F.      05023   Mexico
# 3                120 Hanover Sq.       London    WA1 1DP       UK
# 4                 Berguvsvägen 8        Luleå   S-958 22   Sweden

# %%
df.tail()
# Out:
#     CustomerID            CustomerName       ContactName  \
# 86          87          Wartian Herkku  Pirkko Koskitalo
# 87          88  Wellington Importadora     Paula Parente
# 88          89    White Clover Markets    Karl Jablonski
# 89          90             Wilman Kala   Matti Karttunen
# 90          91                  Wolski           Zbyszek
#
#                         Address      City PostalCode  Country
# 86                  Torikatu 38      Oulu      90110  Finland
# 87           Rua do Mercado, 12   Resende  08737-363   Brazil
# 88  305 - 14th Ave. S. Suite 3B   Seattle      98128      USA
# 89                Keskuskatu 45  Helsinki      21240  Finland
# 90              ul. Filtrowa 68     Walla     01-012   Poland

# %%
list_nama = df['CustomerName'].tolist()

# %%
list_nama
# Out:
# ['Alfreds Futterkiste',
#  'Ana Trujillo Emparedados y helados',
#  'Antonio Moreno Taquería',
#  'Around the Horn',
#  'Berglunds snabbköp',
#  'Blauer See Delikatessen',
#  'Blondel père et fils',
#  'Bólido Comidas preparadas',
#  "Bon app'",
#  'Bottom-Dollar Marketse',
#  "B's Beverages",
#  'Cactus Comidas para llevar',
#  'Centro comercial Moctezuma',
#  'Chop-suey Chinese',
#  'Comércio Mineiro',
#  'Consolidated Holdings',
#  'Drachenblut Delikatessend',
#  'Du monde entier',
#  'Eastern Connection',
#  'Ernst Handel',
#  'Familia Arquibaldo',
#  'FISSA Fabrica Inter. Salchichas S.A.',
#  'Folies gourmandes',
#  'Folk och fä HB',
#  'Frankenversand',
#  'France restauration',
#  'Franchi S.p.A.',
#  'Furia Bacalhau e Frutos do Mar',
#  'Galería del gastrónomo',
#  'Godos Cocina Típica',
#  'Gourmet Lanchonetes',
#  'Great Lakes Food Market',
#  'GROSELLA-Restaurante',
#  'Hanari Carnes',
#  'HILARIÓN-Abastos',
#  'Hungry Coyote Import Store',
# ...

# %%
list_nama[0]
# Out:
# 'Alfreds Futterkiste'

# %%
for index, data in enumerate(list_nama):
    print(index, data)
# Out:
# 0 Alfreds Futterkiste
# 1 Ana Trujillo Emparedados y helados
# 2 Antonio Moreno Taquería
# 3 Around the Horn
# 4 Berglunds snabbköp
# 5 Blauer See Delikatessen
# 6 Blondel père et fils
# 7 Bólido Comidas preparadas
# 8 Bon app'
# 9 Bottom-Dollar Marketse
# 10 B's Beverages
# 11 Cactus Comidas para llevar
# 12 Centro comercial Moctezuma
# 13 Chop-suey Chinese
# 14 Comércio Mineiro
# 15 Consolidated Holdings
# 16 Drachenblut Delikatessend
# 17 Du monde entier
# 18 Eastern Connection
# 19 Ernst Handel
# 20 Familia Arquibaldo
# 21 FISSA Fabrica Inter. Salchichas S.A.
# 22 Folies gourmandes
# 23 Folk och fä HB
# 24 Frankenversand
# 25 France restauration
# 26 Franchi S.p.A.
# 27 Furia Bacalhau e Frutos do Mar
# 28 Galería del gastrónomo
# 29 Godos Cocina Típica
# 30 Gourmet Lanchonetes
# 31 Great Lakes Food Market
# 32 GROSELLA-Restaurante
# 33 Hanari Carnes
# 34 HILARIÓN-Abastos
# 35 Hungry Coyote Import Store
# 36 Hungry Owl All-Night Grocers
# 37 Island Trading
# 38 Königlich Essen
# ...

# %%
df
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
df['City'] == "Berlin"
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# Name: City, Length: 91, dtype: bool

# %%
df[df['City'] == "Berlin"]
# Out:
#    CustomerID         CustomerName   ContactName        Address    City  \
# 0           1  Alfreds Futterkiste  Maria Anders  Obere Str. 57  Berlin
#
#   PostalCode  Country
# 0      12209  Germany

# %%
df['Country'].value_counts()
# Out:
# USA            13
# Germany        11
# France         11
# Brazil          9
# UK              7
# Spain           5
# Mexico          5
# Venezuela       4
# Canada          3
# Argentina       3
# Italy           3
# Finland         2
# Denmark         2
# Belgium         2
# Austria         2
# Portugal        2
# Switzerland     2
# Sweden          2
# Ireland         1
# Norway          1
# Poland          1
# Name: Country, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['Germany', 'Mexico', 'UK', 'Sweden', 'France', 'Spain', 'Canada',
#        'Argentina', 'Switzerland', 'Brazil', 'Austria', 'Italy',
#        'Portugal', 'USA', 'Venezuela', 'Ireland', 'Belgium', 'Norway',
#        'Denmark', 'Finland', 'Poland'], dtype=object)

# %%
len(df['Country'].unique())
# Out:
# 21

# %%
df['Country'].value_counts().head()
# Out:
# USA        13
# Germany    11
# France     11
# Brazil      9
# UK          7
# Name: Country, dtype: int64

# %%
df['Country'].value_counts().head().plot(kind='pie', autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
df.describe()
# Out:
#        CustomerID
# count    91.00000
# mean     46.00000
# std      26.41338
# min       1.00000
# 25%      23.50000
# 50%      46.00000
# 75%      68.50000
# max      91.00000
